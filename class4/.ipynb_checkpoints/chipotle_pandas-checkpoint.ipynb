# %%
#Use the Chipotle Data in PANDAS and come up with some results to a few questions
#that weren't asked before. (i.e. how many soda drinkers like guacamole?)

# %%
import pandas as pd
chipotle = pd.read_table('chipotle.tsv',sep ='\t')

# %%
chipotle.columns
# Out:
# Index([u'order_id', u'quantity', u'item_name', u'choice_description',
#        u'item_price'],
#       dtype='object')

# %%
chipotle.item_name[chipotle.item_name.str.contains("Veggie")].value_counts()
#This returns all item_names that contain the word Veggie
# Out:
# Veggie Burrito         95
# Veggie Bowl            85
# Veggie Salad Bowl      18
# Veggie Soft Tacos       7
# Veggie Salad            6
# Veggie Crispy Tacos     1
# dtype: int64

# %%
chipotle.item_name[chipotle.item_name.str.contains("Chicken")].value_counts()
# Out:
# Chicken Bowl            726
# Chicken Burrito         553
# Chicken Soft Tacos      115
# Chicken Salad Bowl      110
# Chicken Crispy Tacos     47
# Chicken Salad             9
# dtype: int64

# %%
chipotle.item_name[chipotle.item_name.str.contains("Steak")].value_counts()
# Out:
# Steak Burrito         368
# Steak Bowl            211
# Steak Soft Tacos       55
# Steak Crispy Tacos     35
# Steak Salad Bowl       29
# Steak Salad             4
# dtype: int64

# %%
chipotle[chipotle.item_name.str.contains("Barbacoa")]
# Out:
#       order_id  quantity              item_name  \
# 21          11         1       Barbacoa Burrito
# 39          19         1          Barbacoa Bowl
# 56          26         1    Barbacoa Soft Tacos
# 58          27         1          Barbacoa Bowl
# 81          36         1       Barbacoa Burrito
# 95          42         1          Barbacoa Bowl
# 115         51         1          Barbacoa Bowl
# 121         53         1       Barbacoa Burrito
# 127         56         1          Barbacoa Bowl
# 130         57         1       Barbacoa Burrito
# 136         61         1          Barbacoa Bowl
# 144         65         1       Barbacoa Burrito
# 168         75         1  Barbacoa Crispy Tacos
# 181         82         1    Barbacoa Soft Tacos
# 219         97         1          Barbacoa Bowl
# 222         98         1       Barbacoa Burrito
# 249        108         1       Barbacoa Burrito
# 254        110         1          Barbacoa Bowl
# ...

# %%
chipotle.item_name.value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Chips                                    211
# Steak Bowl                               211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
chipotle[chipotle.item_name.str.contains("Chicken")]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# 16           8         1       Chicken Burrito
# 17           9         1       Chicken Burrito
# 19          10         1          Chicken Bowl
# 23          12         1       Chicken Burrito
# 26          13         1          Chicken Bowl
# 29          15         1       Chicken Burrito
# 35          18         1    Chicken Soft Tacos
# 36          18         1    Chicken Soft Tacos
# 42          20         1          Chicken Bowl
# 44          20         1    Chicken Salad Bowl
# 45          21         1       Chicken Burrito
# 52          24         1       Chicken Burrito
# 63          28         1       Chicken Burrito
# 68          30         1       Chicken Burrito
# ...

# %%
chipotle.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipotle[chipotle.choice_description.str.contains("Guacamole", na=False) & chipotle.item_name.str.contains("Salad", na=False)]
# Out:
#       order_id  quantity            item_name  \
# 135         60         2   Chicken Salad Bowl
# 186         83         1    Veggie Salad Bowl
# 213         94         2   Chicken Salad Bowl
# 250        109         1        Chicken Salad
# 281        123         2     Steak Salad Bowl
# 295        128         1    Veggie Salad Bowl
# 455        195         1    Veggie Salad Bowl
# 496        207         1    Veggie Salad Bowl
# 591        243         2   Chicken Salad Bowl
# 606        250         1     Steak Salad Bowl
# 613        253         2     Steak Salad Bowl
# 633        261         2   Chicken Salad Bowl
# 749        309         1     Steak Salad Bowl
# 816        337         2   Chicken Salad Bowl
# 864        357         2   Chicken Salad Bowl
# 1065       439         1        Chicken Salad
# 1110       459         2   Chicken Salad Bowl
# 1132       468         1  Carnitas Salad Bowl
# 1159       478         1     Steak Salad Bowl
# ...

# %%
[float(i.replace("$","").replace(" ","")) for i in chipotle.item_price]
#chipotle.insert(1,'item_price2',chipotle[float(chipotle.item_price.replace("$","").replace(" ",""))])
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 6            3         1                          Side of Chips
# 10           5         1                    Chips and Guacamole
# 14           7         1                    Chips and Guacamole
# 15           8         1  Chips and Tomatillo-Green Chili Salsa
# 20          10         1                    Chips and Guacamole
# 25          13         1           Chips and Fresh Tomato Salsa
# 30          15         1  Chips and Tomatillo-Green Chili Salsa
# 32          16         1                          Side of Chips
# 37          18         1                    Chips and Guacamole
# 38          18         1  Chips and Tomatillo Green Chili Salsa
# 40          19         1                                  Chips
# 41          20         1                    Chips and Guacamole
# ...

# %%
chips_only = chipotle[chipotle.item_name.str.contains("Chips")].groupby('item_name').order_id.count() #DF of only item_names with chips

# %%
chips_only
# Out:
# item_name
# Chips                                    211
# Chips and Fresh Tomato Salsa             110
# Chips and Guacamole                      479
# Chips and Mild Fresh Tomato Salsa          1
# Chips and Roasted Chili Corn Salsa        22
# Chips and Roasted Chili-Corn Salsa        18
# Chips and Tomatillo Green Chili Salsa     43
# Chips and Tomatillo Red Chili Salsa       48
# Chips and Tomatillo-Green Chili Salsa     31
# Chips and Tomatillo-Red Chili Salsa       20
# Side of Chips                            101
# Name: order_id, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-be49202fe3d4> in <module>()
# ----> 1 chips_dict = dict(zip(chipotle.item_name, chipotle.count))
#
# TypeError: zip argument #2 must support iteration
